# %%
import yfinance as yf

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(period="max")
# Out:
# c:\Users\HomePC\miniconda3\envs\simulation\Lib\site-packages\yfinance\utils.py:771: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-10-28 00:00:00-04:00  5833.930176  5842.919922  5823.080078  5823.520020
# 2024-10-29 00:00:00-04:00  5819.680176  5847.189941  5802.169922  5832.919922
# 2024-10-30 00:00:00-04:00  5832.649902  5850.939941  5811.279785  5813.669922
# 2024-10-31 00:00:00-04:00  5775.339844  5775.339844  5702.859863  5705.450195
# 2024-11-01 00:00:00-04:00  5723.220215  5772.520020  5723.220215  5728.799805
#
#                                Volume  Dividends  Stock Splits
# Date
# 1927-12-30 00:00:00-05:00           0        0.0           0.0
# 1928-01-03 00:00:00-05:00           0        0.0           0.0
# 1928-01-04 00:00:00-05:00           0        0.0           0.0
# 1928-01-05 00:00:00-05:00           0        0.0           0.0
# 1928-01-06 00:00:00-05:00           0        0.0           0.0
# ...                               ...        ...           ...
# 2024-10-28 00:00:00-04:00  3691280000        0.0           0.0
# 2024-10-29 00:00:00-04:00  3879100000        0.0           0.0
# 2024-10-30 00:00:00-04:00  3851120000        0.0           0.0
# 2024-10-31 00:00:00-04:00  4425660000        0.0           0.0
# 2024-11-01 00:00:00-04:00  3796450000        0.0           0.0
#
# [24327 rows x 7 columns]

# %%
sp500.plot.line(y="Close",use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500['Tomorrow'] = sp500["Close"].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-10-28 00:00:00-04:00  5833.930176  5842.919922  5823.080078  5823.520020
# 2024-10-29 00:00:00-04:00  5819.680176  5847.189941  5802.169922  5832.919922
# 2024-10-30 00:00:00-04:00  5832.649902  5850.939941  5811.279785  5813.669922
# 2024-10-31 00:00:00-04:00  5775.339844  5775.339844  5702.859863  5705.450195
# 2024-11-01 00:00:00-04:00  5723.220215  5772.520020  5723.220215  5728.799805
#
#                                Volume     Tomorrow
# Date
# 1927-12-30 00:00:00-05:00           0    17.760000
# 1928-01-03 00:00:00-05:00           0    17.719999
# 1928-01-04 00:00:00-05:00           0    17.549999
# 1928-01-05 00:00:00-05:00           0    17.660000
# 1928-01-06 00:00:00-05:00           0    17.500000
# ...                               ...          ...
# 2024-10-28 00:00:00-04:00  3691280000  5832.919922
# 2024-10-29 00:00:00-04:00  3879100000  5813.669922
# 2024-10-30 00:00:00-04:00  3851120000  5705.450195
# 2024-10-31 00:00:00-04:00  4425660000  5728.799805
# 2024-11-01 00:00:00-04:00  3796450000          NaN
#
# [24327 rows x 6 columns]

# %%
sp500["Target"] = (sp500["Tomorrow"]>sp500["Close"]).astype(int)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-10-28 00:00:00-04:00  5833.930176  5842.919922  5823.080078  5823.520020
# 2024-10-29 00:00:00-04:00  5819.680176  5847.189941  5802.169922  5832.919922
# 2024-10-30 00:00:00-04:00  5832.649902  5850.939941  5811.279785  5813.669922
# 2024-10-31 00:00:00-04:00  5775.339844  5775.339844  5702.859863  5705.450195
# 2024-11-01 00:00:00-04:00  5723.220215  5772.520020  5723.220215  5728.799805
#
#                                Volume     Tomorrow  Target
# Date
# 1927-12-30 00:00:00-05:00           0    17.760000       1
# 1928-01-03 00:00:00-05:00           0    17.719999       0
# 1928-01-04 00:00:00-05:00           0    17.549999       0
# 1928-01-05 00:00:00-05:00           0    17.660000       1
# 1928-01-06 00:00:00-05:00           0    17.500000       0
# ...                               ...          ...     ...
# 2024-10-28 00:00:00-04:00  3691280000  5832.919922       1
# 2024-10-29 00:00:00-04:00  3879100000  5813.669922       0
# 2024-10-30 00:00:00-04:00  3851120000  5705.450195       0
# 2024-10-31 00:00:00-04:00  4425660000  5728.799805       1
# 2024-11-01 00:00:00-04:00  3796450000          NaN       0
#
# [24327 rows x 7 columns]

# %%
sp500=sp500.loc["1990-01-01":].copy()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2024-10-28 00:00:00-04:00  5833.930176  5842.919922  5823.080078  5823.520020
# 2024-10-29 00:00:00-04:00  5819.680176  5847.189941  5802.169922  5832.919922
# 2024-10-30 00:00:00-04:00  5832.649902  5850.939941  5811.279785  5813.669922
# 2024-10-31 00:00:00-04:00  5775.339844  5775.339844  5702.859863  5705.450195
# 2024-11-01 00:00:00-04:00  5723.220215  5772.520020  5723.220215  5728.799805
#
#                                Volume     Tomorrow  Target
# Date
# 1990-01-02 00:00:00-05:00   162070000   358.760010       0
# 1990-01-03 00:00:00-05:00   192330000   355.670013       0
# 1990-01-04 00:00:00-05:00   177000000   352.200012       0
# 1990-01-05 00:00:00-05:00   158530000   353.790009       1
# 1990-01-08 00:00:00-05:00   140110000   349.619995       0
# ...                               ...          ...     ...
# 2024-10-28 00:00:00-04:00  3691280000  5832.919922       1
# 2024-10-29 00:00:00-04:00  3879100000  5813.669922       0
# 2024-10-30 00:00:00-04:00  3851120000  5705.450195       0
# 2024-10-31 00:00:00-04:00  4425660000  5728.799805       1
# 2024-11-01 00:00:00-04:00  3796450000          NaN       0
#
# [8777 rows x 7 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100,min_samples_split=100,random_state=1)


train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close","Volume","Open","High","Low"]

model.fit(train[predictors],train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd

preds = pd.Series(preds,index = test.index)
preds
# Out:
# Date
# 2024-06-12 00:00:00-04:00    1
# 2024-06-13 00:00:00-04:00    1
# 2024-06-14 00:00:00-04:00    0
# 2024-06-17 00:00:00-04:00    0
# 2024-06-18 00:00:00-04:00    1
#                             ..
# 2024-10-28 00:00:00-04:00    1
# 2024-10-29 00:00:00-04:00    1
# 2024-10-30 00:00:00-04:00    1
# 2024-10-31 00:00:00-04:00    1
# 2024-11-01 00:00:00-04:00    1
# Length: 100, dtype: int32

# %%
precision_score(test["Target"],preds)
# Out:
# 0.5657894736842105

# %%
combined = pd.concat([test["Target"],preds],axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train,test,predictors,model):
    model.fit(train[predictors],train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds,index = test.index,name = "Predictions")
    combined = pd.concat([test["Target"],preds],axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500,model,predictors)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 predictions = backtest(sp500,model,predictors)
#
# Cell In[39], line 7, in backtest(data, model, predictors, start, step)
#       5     train = data.iloc[0:i].copy()
#       6     test = data.iloc[i:(i+step)].copy()
# ----> 7     predictions = predict(train, test, predictors, model)
#       8     all_predictions.append(predictions)
#      10 return pd.concat(all_predictions)
#
# Cell In[37], line 6, in predict(train, test, predictors, model)
#       4 preds[preds>=.6]=1
#       5 preds[preds<.6]=0
# ----> 6 preds = pd.Series(preds,index = test.index,name = "Predictions")
#       7 combined = pd.concat([test["Target"],preds],axis=1)
#       8 return combined
#
# File c:\Users\HomePC\miniconda3\envs\simulation\Lib\site-packages\pandas\core\series.py:584, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     582         data = data.copy()
#     583 else:
# --> 584     data = sanitize_array(data, index, dtype, copy)
#     586     manager = _get_option("mode.data_manager", silent=True)
#     587     if manager == "block":
#
# File c:\Users\HomePC\miniconda3\envs\simulation\Lib\site-packages\pandas\core\construction.py:659, in sanitize_array(data, index, dtype, copy, allow_2d)
#     656             subarr = cast(np.ndarray, subarr)
#     657             subarr = maybe_infer_to_datetimelike(subarr)
# --> 659 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     661 if isinstance(subarr, np.ndarray):
#     662     # at this point we should have dtype be None or subarr.dtype == dtype
#     663     dtype = cast(np.dtype, dtype)
#
# File c:\Users\HomePC\miniconda3\envs\simulation\Lib\site-packages\pandas\core\construction.py:718, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     716     if allow_2d:
#     717         return result
# --> 718     raise ValueError(
#     719         f"Data must be 1-dimensional, got ndarray of shape {data.shape} instead"
#     720     )
#     721 if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     722     # i.e. NumpyEADtype("O")
#     724     result = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
#
# ValueError: Data must be 1-dimensional, got ndarray of shape (250, 2) instead

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    3658
# 1    2619
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.5284459717449408

# %%
predictions["Target"].value_counts()/predictions.shape[0]
# Out:
# Target
# 1    0.535606
# 0    0.464394
# Name: count, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()
    
    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]
    
    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors+= [ratio_column, trend_column]

# %%
sp500 = sp500.dropna()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1997-11-26 00:00:00-05:00   950.820007   956.469971   950.820007   951.640015
# 1997-11-28 00:00:00-05:00   951.640015   959.130005   951.640015   955.400024
# 1997-12-01 00:00:00-05:00   955.400024   974.770020   955.400024   974.770020
# 1997-12-02 00:00:00-05:00   974.780029   976.200012   969.830017   971.679993
# 1997-12-03 00:00:00-05:00   971.679993   980.809998   966.159973   976.770020
# ...                                ...          ...          ...          ...
# 2024-10-25 00:00:00-04:00  5826.750000  5862.819824  5799.979980  5808.120117
# 2024-10-28 00:00:00-04:00  5833.930176  5842.919922  5823.080078  5823.520020
# 2024-10-29 00:00:00-04:00  5819.680176  5847.189941  5802.169922  5832.919922
# 2024-10-30 00:00:00-04:00  5832.649902  5850.939941  5811.279785  5813.669922
# 2024-10-31 00:00:00-04:00  5775.339844  5775.339844  5702.859863  5705.450195
#
#                                Volume     Tomorrow  Target  Close_Ratio_2  \
# Date
# 1997-11-26 00:00:00-05:00   487750000   955.400024       1       1.000431
# 1997-11-28 00:00:00-05:00   189070000   974.770020       1       1.001972
# 1997-12-01 00:00:00-05:00   590300000   971.679993       0       1.010035
# 1997-12-02 00:00:00-05:00   576120000   976.770020       1       0.998412
# 1997-12-03 00:00:00-05:00   624610000   973.099976       0       1.002612
# ...                               ...          ...     ...            ...
# 2024-10-25 00:00:00-04:00  3501280000  5823.520020       1       0.999850
# 2024-10-28 00:00:00-04:00  3691280000  5832.919922       1       1.001324
# 2024-10-29 00:00:00-04:00  3879100000  5813.669922       0       1.000806
# 2024-10-30 00:00:00-04:00  3851120000  5705.450195       0       0.998347
# 2024-10-31 00:00:00-04:00  4425660000  5728.799805       1       0.990605
#
#                            Trend_2  Close_Ratio_5  Trend_5  Close_Ratio_60  \
# Date
# 1997-11-26 00:00:00-05:00      2.0       0.997275      4.0        1.009111
# 1997-11-28 00:00:00-05:00      2.0       1.001967      4.0        1.012659
# 1997-12-01 00:00:00-05:00      2.0       1.019783      4.0        1.032356
# 1997-12-02 00:00:00-05:00      1.0       1.011259      4.0        1.028349
# 1997-12-03 00:00:00-05:00      1.0       1.011095      4.0        1.032949
# ...                            ...            ...      ...             ...
# 2024-10-25 00:00:00-04:00      1.0       0.997254      1.0        1.032411
# 2024-10-28 00:00:00-04:00      1.0       1.000945      2.0        1.033688
# 2024-10-29 00:00:00-04:00      2.0       1.003191      3.0        1.033379
# 2024-10-30 00:00:00-04:00      1.0       0.999321      3.0        1.028227
# 2024-10-31 00:00:00-04:00      0.0       0.984252      2.0        1.007584
#
#                            Trend_60  Close_Ratio_250  Trend_250  \
# Date
# 1997-11-26 00:00:00-05:00      33.0         1.113282      138.0
# 1997-11-28 00:00:00-05:00      33.0         1.116599      139.0
# 1997-12-01 00:00:00-05:00      34.0         1.138015      140.0
# 1997-12-02 00:00:00-05:00      33.0         1.133204      140.0
# 1997-12-03 00:00:00-05:00      33.0         1.137882      141.0
# ...                             ...              ...        ...
# 2024-10-25 00:00:00-04:00      34.0         1.120709      149.0
# 2024-10-28 00:00:00-04:00      35.0         1.122245      149.0
# 2024-10-29 00:00:00-04:00      36.0         1.122638      149.0
# 2024-10-30 00:00:00-04:00      35.0         1.117578      148.0
# 2024-10-31 00:00:00-04:00      35.0         1.095605      147.0
#
#                            Close_Ratio_1000  Trend_1000
# Date
# 1997-11-26 00:00:00-05:00          1.517046       563.0
# 1997-11-28 00:00:00-05:00          1.521842       564.0
# 1997-12-01 00:00:00-05:00          1.551433       564.0
# 1997-12-02 00:00:00-05:00          1.545272       563.0
# 1997-12-03 00:00:00-05:00          1.552105       564.0
# ...                                     ...         ...
# 2024-10-25 00:00:00-04:00          1.313441       527.0
# 2024-10-28 00:00:00-04:00          1.316216       527.0
# 2024-10-29 00:00:00-04:00          1.317648       527.0
# 2024-10-30 00:00:00-04:00          1.312617       527.0
# 2024-10-31 00:00:00-04:00          1.287556       526.0
#
# [6776 rows x 17 columns]

# %%
model = RandomForestClassifier(n_estimators=200,min_samples_split=50,random_state=1)

# %%
def predict(train,test,predictors,model):
    model.fit(train[predictors],train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds>=.6]=1
    preds[preds<.6]=0
    preds = pd.Series(preds,index = test.index,name = "Predictions")
    combined = pd.concat([test["Target"],preds],axis=1)
    return combined

# %%
predictions = backtest(sp500,model,new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    3706
# 1.0     570
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.5684210526315789
